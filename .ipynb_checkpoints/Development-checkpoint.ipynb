# %%
run stage1.py
# Out:
# -------------
# Summary 1
# Management Mode:  UCSM
# Management IP:  10.254.1.4
# Name:  UCS01-5
# CPU Capacity:  30
# Number of cores:  12
# on
# 3.0(3a)
# UCSC-C220-M3S
# FCH1702V12K
# UCS01-5
# -------------
# Summary 2
# Management Mode:  UCSM
# Management IP:  10.254.1.6
# Name:  UCS01-2
# CPU Capacity:  72.799995
# Number of cores:  28
# on
# 4.0(2l)
# HXAF240C-M4SX
# FCH2117V32K
# UCS01-2
# -------------
# Summary 3
# Management Mode:  UCSM
# Management IP:  10.254.1.5
# Name:  UCS01-1
# CPU Capacity:  72.799995
# Number of cores:  28
# on
# 4.0(2l)
# HXAF240C-M4SX
# FCH2117V3DQ
# UCS01-1
# -------------
# Summary 4
# Management Mode:  UCSM
# Management IP:  10.254.1.8
# Name:  UCS01-4
# CPU Capacity:  72.799995
# Number of cores:  28
# on
# 4.0(2l)
# HXAF240C-M4SX
# FCH2117V2VQ
# UCS01-4
# -------------
# Summary 5
# Management Mode:  UCSM
# Management IP:  10.254.1.7
# Name:  UCS01-3
# CPU Capacity:  72.799995
# Number of cores:  28
# on
# 4.0(2l)
# HXAF240C-M4SX
# ...

# %%
run stage1.py
# Out:
# UCS01-5
# UCS01-2
# UCS01-1
# UCS01-4
# UCS01-3
# C220-FCH2017V15X
# HX-Robotics-1
# HX-Robotics-2
# {'ObjectType': 'compute.PhysicalSummary.List',
#  'Results': [{'AccountMoid': '59b27d41f11aa100012bd191',
#               'AdminPowerState': 'policy',
#               'AlarmSummary': {'ClassId': 'compute.AlarmSummary',
#                                'Critical': 2,
#                                'ObjectType': 'compute.AlarmSummary',
#                                'Warning': 2},
#               'Ancestors': [],
#               'AssetTag': '',
#               'AvailableMemory': 180224,
#               'BiosPostComplete': False,
#               'ChassisId': '',
#               'ClassId': 'compute.PhysicalSummary',
#               'ConnectionStatus': 'A,B',
#               'CpuCapacity': 30,
#               'CreateTime': '2018-04-16T06:09:09.5Z',
#               'DeviceMoId': '5ad43da137726e6c33bccba1',
#               'Dn': 'sys/rack-unit-5',
# ...
